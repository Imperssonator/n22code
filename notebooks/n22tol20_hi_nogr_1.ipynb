# %% [markdown]
# # N2200 in situ blade coating

# %% [markdown]
# ### Import python libraries

# %%
# numpy and plotting
import numpy as np
from scipy.signal import convolve2d
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True,
                 'xtick.top': True,
                 'xtick.direction': 'in',
                 'ytick.right': True,
                 'ytick.direction': 'in',
                 'font.sans-serif': 'Arial',
                 'font.size': 10
                })
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['figure.dpi'] = 96

# Data handling
import os
import glob
import pandas as pd

# pyFAI
import pyFAI
from pyFAI.multi_geometry import MultiGeometry
from pyFAI.calibrant import get_calibrant
# from pyFAI.gui import jupyter

# pygix
import pygix
import fabio
from pygix import plotting as ppl

# Peak Fitting
from lmfit.models import GaussianModel, LorentzianModel, ExponentialModel, ConstantModel, LinearModel, VoigtModel
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Load data files
#
# Also define fundamental constants for this experiment

# %%
run_name = 'n22tol20_hi_nogr_1'

tiff_folder = "F:\\N2200 Project\\data\\chess_apr18\\{}".format(run_name)
waxs_glob = glob.glob(os.path.join(tiff_folder, "*.tiff"))
uv_straight = glob.glob("F:\\N2200 Project\\data\\chess_apr18\\wli\\{}\\straight\\*.txt".format(run_name))
uv_kicked = glob.glob("F:\\N2200 Project\\data\\chess_apr18\\wli\\{}\\kicked\\*.txt".format(run_name))

figfolder = tiff_folder.replace('data','figures')
os.makedirs(os.path.join(figfolder,'raw_waxs'),exist_ok=True)
os.makedirs(os.path.join(figfolder,'raw_uv'),exist_ok=True)

xray_dt = 0.2  # 0.2s per xray image
uv_dt = 0.1    # 0.1s per UV acquisition

# %% [markdown]
# ## Parse file names and build master dataframe for results
#
# These all followed the same alignment and run scripts, so we can write lists of thetas and exposure times that correspond to the movie numbers

# %%
def parse_filename(file):
    
    parts = file.split('_')
    parsed = pd.Series()
    
    parsed['solvent'] = parts[0]
    parsed['speed'] = parts[1]
    parsed['grooves'] = parts[2]
    parsed['repeat'] = parts[3]
    parsed['movie_num'] = int(parts[4])
    parsed['shot_num'] = int(parts[5][:-5])
    
    thetas = [0.12, 0.12, 0.12, 0.12, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.12]
    exp_times = [0.1, 0.1, 3, 0.2, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]
    
    parsed['theta'] = thetas[parsed['movie_num']]
    parsed['exp_time'] = exp_times[parsed['movie_num']]
        
    return parsed

# %%
df = pd.DataFrame()
df['fullpath'] = pd.Series(waxs_glob)
df['filename'] = pd.Series([s[-1] for s in df['fullpath'].str.split('\\')])
df = pd.concat([df, df['filename'].apply(parse_filename)],
                      axis=1)
df
# Out:
#                                               fullpath  \
# 0    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 1    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 2    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 3    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 4    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 5    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 6    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 7    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 8    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 9    F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 10   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 11   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 12   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 13   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 14   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 15   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 16   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 17   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 18   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 19   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 20   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 21   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 22   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 23   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 24   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 25   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 26   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 27   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 28   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 29   F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# ..                                                 ...
# 579  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 580  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 581  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 582  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 583  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 584  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 585  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 586  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 587  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 588  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 589  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 590  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 591  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 592  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 593  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 594  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 595  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 596  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 597  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 598  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 599  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 600  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 601  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 602  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 603  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 604  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 605  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 606  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 607  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
# 608  F:\N2200 Project\data\chess_apr18\n22tol20_hi_...
#
#                             filename   solvent speed grooves repeat  \
# 0    n22tol20_hi_nogr_1_10_0000.tiff  n22tol20    hi    nogr      1
# 1     n22tol20_hi_nogr_1_1_0000.tiff  n22tol20    hi    nogr      1
# 2     n22tol20_hi_nogr_1_2_0000.tiff  n22tol20    hi    nogr      1
# 3     n22tol20_hi_nogr_1_3_0000.tiff  n22tol20    hi    nogr      1
# 4     n22tol20_hi_nogr_1_3_0001.tiff  n22tol20    hi    nogr      1
# 5     n22tol20_hi_nogr_1_3_0002.tiff  n22tol20    hi    nogr      1
# 6     n22tol20_hi_nogr_1_3_0003.tiff  n22tol20    hi    nogr      1
# 7     n22tol20_hi_nogr_1_3_0004.tiff  n22tol20    hi    nogr      1
# 8     n22tol20_hi_nogr_1_3_0005.tiff  n22tol20    hi    nogr      1
# 9     n22tol20_hi_nogr_1_3_0006.tiff  n22tol20    hi    nogr      1
# 10    n22tol20_hi_nogr_1_3_0007.tiff  n22tol20    hi    nogr      1
# 11    n22tol20_hi_nogr_1_3_0008.tiff  n22tol20    hi    nogr      1
# 12    n22tol20_hi_nogr_1_3_0009.tiff  n22tol20    hi    nogr      1
# 13    n22tol20_hi_nogr_1_3_0010.tiff  n22tol20    hi    nogr      1
# 14    n22tol20_hi_nogr_1_3_0011.tiff  n22tol20    hi    nogr      1
# 15    n22tol20_hi_nogr_1_3_0012.tiff  n22tol20    hi    nogr      1
# 16    n22tol20_hi_nogr_1_3_0013.tiff  n22tol20    hi    nogr      1
# 17    n22tol20_hi_nogr_1_3_0014.tiff  n22tol20    hi    nogr      1
# 18    n22tol20_hi_nogr_1_3_0015.tiff  n22tol20    hi    nogr      1
# 19    n22tol20_hi_nogr_1_3_0016.tiff  n22tol20    hi    nogr      1
# 20    n22tol20_hi_nogr_1_3_0017.tiff  n22tol20    hi    nogr      1
# 21    n22tol20_hi_nogr_1_3_0018.tiff  n22tol20    hi    nogr      1
# 22    n22tol20_hi_nogr_1_3_0019.tiff  n22tol20    hi    nogr      1
# 23    n22tol20_hi_nogr_1_3_0020.tiff  n22tol20    hi    nogr      1
# 24    n22tol20_hi_nogr_1_3_0021.tiff  n22tol20    hi    nogr      1
# 25    n22tol20_hi_nogr_1_3_0022.tiff  n22tol20    hi    nogr      1
# 26    n22tol20_hi_nogr_1_3_0023.tiff  n22tol20    hi    nogr      1
# 27    n22tol20_hi_nogr_1_3_0024.tiff  n22tol20    hi    nogr      1
# 28    n22tol20_hi_nogr_1_3_0025.tiff  n22tol20    hi    nogr      1
# 29    n22tol20_hi_nogr_1_3_0026.tiff  n22tol20    hi    nogr      1
# ..                               ...       ...   ...     ...    ...
# 579   n22tol20_hi_nogr_1_3_0576.tiff  n22tol20    hi    nogr      1
# 580   n22tol20_hi_nogr_1_3_0577.tiff  n22tol20    hi    nogr      1
# 581   n22tol20_hi_nogr_1_3_0578.tiff  n22tol20    hi    nogr      1
# 582   n22tol20_hi_nogr_1_3_0579.tiff  n22tol20    hi    nogr      1
# 583   n22tol20_hi_nogr_1_3_0580.tiff  n22tol20    hi    nogr      1
# 584   n22tol20_hi_nogr_1_3_0581.tiff  n22tol20    hi    nogr      1
# 585   n22tol20_hi_nogr_1_3_0582.tiff  n22tol20    hi    nogr      1
# 586   n22tol20_hi_nogr_1_3_0583.tiff  n22tol20    hi    nogr      1
# 587   n22tol20_hi_nogr_1_3_0584.tiff  n22tol20    hi    nogr      1
# 588   n22tol20_hi_nogr_1_3_0585.tiff  n22tol20    hi    nogr      1
# 589   n22tol20_hi_nogr_1_3_0586.tiff  n22tol20    hi    nogr      1
# 590   n22tol20_hi_nogr_1_3_0587.tiff  n22tol20    hi    nogr      1
# 591   n22tol20_hi_nogr_1_3_0588.tiff  n22tol20    hi    nogr      1
# 592   n22tol20_hi_nogr_1_3_0589.tiff  n22tol20    hi    nogr      1
# 593   n22tol20_hi_nogr_1_3_0590.tiff  n22tol20    hi    nogr      1
# 594   n22tol20_hi_nogr_1_3_0591.tiff  n22tol20    hi    nogr      1
# 595   n22tol20_hi_nogr_1_3_0592.tiff  n22tol20    hi    nogr      1
# 596   n22tol20_hi_nogr_1_3_0593.tiff  n22tol20    hi    nogr      1
# 597   n22tol20_hi_nogr_1_3_0594.tiff  n22tol20    hi    nogr      1
# 598   n22tol20_hi_nogr_1_3_0595.tiff  n22tol20    hi    nogr      1
# 599   n22tol20_hi_nogr_1_3_0596.tiff  n22tol20    hi    nogr      1
# 600   n22tol20_hi_nogr_1_3_0597.tiff  n22tol20    hi    nogr      1
# 601   n22tol20_hi_nogr_1_3_0598.tiff  n22tol20    hi    nogr      1
# 602   n22tol20_hi_nogr_1_3_0599.tiff  n22tol20    hi    nogr      1
# 603   n22tol20_hi_nogr_1_4_0000.tiff  n22tol20    hi    nogr      1
# 604   n22tol20_hi_nogr_1_5_0000.tiff  n22tol20    hi    nogr      1
# 605   n22tol20_hi_nogr_1_6_0000.tiff  n22tol20    hi    nogr      1
# 606   n22tol20_hi_nogr_1_7_0000.tiff  n22tol20    hi    nogr      1
# 607   n22tol20_hi_nogr_1_8_0000.tiff  n22tol20    hi    nogr      1
# 608   n22tol20_hi_nogr_1_9_0000.tiff  n22tol20    hi    nogr      1
#
#      movie_num  shot_num  theta  exp_time
# 0           10         0   0.12       3.5
# 1            1         0   0.12       0.1
# 2            2         0   0.12       3.0
# 3            3         0   0.12       0.2
# 4            3         1   0.12       0.2
# 5            3         2   0.12       0.2
# 6            3         3   0.12       0.2
# 7            3         4   0.12       0.2
# 8            3         5   0.12       0.2
# 9            3         6   0.12       0.2
# 10           3         7   0.12       0.2
# 11           3         8   0.12       0.2
# 12           3         9   0.12       0.2
# 13           3        10   0.12       0.2
# 14           3        11   0.12       0.2
# 15           3        12   0.12       0.2
# 16           3        13   0.12       0.2
# 17           3        14   0.12       0.2
# 18           3        15   0.12       0.2
# 19           3        16   0.12       0.2
# 20           3        17   0.12       0.2
# 21           3        18   0.12       0.2
# 22           3        19   0.12       0.2
# 23           3        20   0.12       0.2
# 24           3        21   0.12       0.2
# 25           3        22   0.12       0.2
# 26           3        23   0.12       0.2
# 27           3        24   0.12       0.2
# 28           3        25   0.12       0.2
# 29           3        26   0.12       0.2
# ..         ...       ...    ...       ...
# 579          3       576   0.12       0.2
# 580          3       577   0.12       0.2
# 581          3       578   0.12       0.2
# 582          3       579   0.12       0.2
# 583          3       580   0.12       0.2
# 584          3       581   0.12       0.2
# 585          3       582   0.12       0.2
# 586          3       583   0.12       0.2
# 587          3       584   0.12       0.2
# 588          3       585   0.12       0.2
# 589          3       586   0.12       0.2
# 590          3       587   0.12       0.2
# 591          3       588   0.12       0.2
# 592          3       589   0.12       0.2
# 593          3       590   0.12       0.2
# 594          3       591   0.12       0.2
# 595          3       592   0.12       0.2
# 596          3       593   0.12       0.2
# 597          3       594   0.12       0.2
# 598          3       595   0.12       0.2
# 599          3       596   0.12       0.2
# 600          3       597   0.12       0.2
# 601          3       598   0.12       0.2
# 602          3       599   0.12       0.2
# 603          4         0   0.04       3.5
# 604          5         0   0.06       3.5
# 605          6         0   0.08       3.5
# 606          7         0   0.10       3.5
# 607          8         0   0.12       3.5
# 608          9         0   0.14       3.5
#
# [609 rows x 10 columns]

# %% [markdown]
# ### Load example file for exploratory analysis

# %%
sample = 602
dark_movie = 2
main_movie = 3
dual_movie = 10
aoi_start = 4

data_file = df['fullpath'].loc[sample]
data_exp = df['exp_time'].loc[sample]
data = fabio.open(data_file).data
data = np.flipud(data)
dark_file = df.query('movie_num == {}'.format(dark_movie)).iloc[0]['fullpath']
dark_exp = df.query('movie_num == {}'.format(dark_movie)).iloc[0]['exp_time']
dark = np.flipud(fabio.open(dark_file).data)
darkscale = (data_exp/dark_exp)*dark

# %% [markdown]
# ## Show raw detector data in log scale

# %%
# %matplotlib notebook

corrdata = data - darkscale
logdata = np.log(corrdata-np.min(corrdata)+1)

lmin, lmax = np.percentile(logdata, (2, 99.9))
plt.figure()
plt.imshow(logdata,cmap='terrain',vmin=lmin,vmax=lmax,origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="312">

# %% [markdown]
# ## Define pyFAI detector parameters

# %%
### Detector pixel size
det_pix = [172e-6, 172e-6]

detector = pyFAI.detectors.Detector(det_pix[0], det_pix[1])

### Wavelength
wl = 0.97e-10

### Center-pixel and sample-to-detector distance
centerx =  448.248
centery = data.shape[0]-381.901   # This is because I had to flip it upside-down
sdd = 179.284e-3

### Beamcenter from sample view in meters from lower left of detector
poni1 = centery * det_pix[1]; poni2 = centerx * det_pix[0]

### detector rotations from sample view
rot1 = 0.0    /180 * np.pi # move detector to right, in-plane angle# in radians
rot2 = 0.0    /180 * np.pi # move detector down, out-of-plane angle
rot3 = 0.0    /180 * np.pi # clockwise rotation

# Orientations and Angles
sample_orientation = 1    # 1 is horizontal, 2 is vertical
incident_angle = df['theta'].loc[sample]     # indicent angle in deg
tilt_angle = 0            # tilt angle of sample in deg (misalignment in "chi")

# %% [markdown]
# ## Setup detector and sample geometry, Get qxy-qz data

# %%
pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = incident_angle, tilt_angle = tilt_angle,
                     detector=detector)

imgt, qxy, qz = pg.transform_reciprocal(data, method='lut', correctSolidAngle=True, unit='A', dark=darkscale)
corrimg = imgt-np.min(imgt)+1
logimg = np.log(corrimg)

clim = np.percentile(logimg, (2.5, 99.8))
ppl.implot(logimg, qxy, qz, mode='rsma', cmap="terrain", clim=clim, xlim=(-0.2,2), ylim=(-0.05,2))
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':
# <img src="data:image/png;base64,..." width="312">
# (<matplotlib.figure.Figure at 0xc3bbef0>,
#  <matplotlib.image.AxesImage at 0xc7d19e8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xc3c69b0>)

# %% [markdown]
# ## Peep the nice dual image

# %%
dual_file = os.path.join(os.path.split(figfolder)[0],'{}_dual.png'.format(run_name))

dual_tiff = df['fullpath'].loc[df['movie_num']==dual_movie].iloc[0]
dual_exp = df['exp_time'].loc[df['movie_num']==dual_movie].iloc[0]
dual_data = fabio.open(dual_tiff).data
dual_data = np.flipud(dual_data)
darkscale_dual = (dual_exp/dark_exp)*dark

pg2 = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = incident_angle, tilt_angle = tilt_angle,
                     detector=detector)

dualt, qxy, qz = pg2.transform_reciprocal(dual_data, method='lut', correctSolidAngle=True, unit='A', dark=darkscale_dual)
corrdual = dualt-np.min(dualt)+1
logdual = np.log(corrdual)

clim = np.percentile(logdual, (2.5, 99.8))
ppl.implot(logdual, qxy, qz, mode='rsma', cmap="terrain",
           clim=clim, xlim=(-0.2,2), ylim=(-0.05,2),
           filename=dual_file)
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':
# <img src="data:image/png;base64,..." width="312">
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# (<matplotlib.figure.Figure at 0xbb18438>,
#  <matplotlib.image.AxesImage at 0xccdb080>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xba1e080>)

# %% [markdown]
# ## Look at the AOI series

# %%
plt.figure(figsize=(9,6))
aoi_file = os.path.join(os.path.split(figfolder)[0],'{}_aoi_series.png'.format(run_name))

for i in range(6):
    
    temp_movie_num = i + aoi_start
    aoi_tiff = df['fullpath'].loc[df['movie_num']==temp_movie_num].iloc[0]
    aoi_exp = df['exp_time'].loc[df['movie_num']==temp_movie_num].iloc[0]
    aoi_data = fabio.open(aoi_tiff).data
    aoi_data = np.flipud(aoi_data)
    darkscale_aoi = (aoi_exp/dark_exp)*dark

    pg3 = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                         rot1 = rot1, rot2 = rot2, rot3 = rot3,
                         wavelength = wl, sample_orientation = sample_orientation,
                         incident_angle = incident_angle, tilt_angle = tilt_angle,
                         detector=detector)

    aoit, qxy, qz = pg3.transform_reciprocal(aoi_data, method='lut', correctSolidAngle=True, unit='A', dark=darkscale_aoi)
    corraoi = aoit-np.min(aoit)+1
    logaoi = np.log(corraoi)
    
    clim = np.percentile(logaoi, (2.5, 99.8))
    plt.subplot(2,3,i+1)
    ppl.implot(logaoi, qxy, qz, mode='rsma', cmap="terrain",
               clim=clim, xlim=(-0.2,2), ylim=(-0.05,2),
               newfig=False)
    
plt.savefig(aoi_file)
# Out:
# <img src="data:image/png;base64,..." width="864">
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':

# %% [markdown]
# ## Get out-of-plane sector
#
# Then do this for all runs and plot vs. time

# %%
# %matplotlib notebook
int_sect, q_sect = pg.profile_sector(data, npt=1000, chi_pos=86,
                                 chi_width=4, radial_range=(1.35, 20),
                                 correctSolidAngle=True,
                                 method='lut', dark=darkscale)
ppl.plot(q_sect,int_sect, logy=False)
# Out:
# <img src="data:image/png;base64,..." width="312">

# %%
df['sect86'] = df['fullpath'].apply(lambda f:
                                    pg.profile_sector(
                                        np.flipud(fabio.open(f).data), npt=1000, chi_pos=86,
                                         chi_width=4, radial_range=(1.35, 20),
                                         correctSolidAngle=True,
                                         method='lut', dark=darkscale)[0]
                                   )

sect_array = np.array(df.loc[df['movie_num']==main_movie]['sect86'].tolist())
log_sect_array = np.log(sect_array-np.min(sect_array)+1)
log_sect_array.shape
# Out:
# (600, 1000)

# %%
# %matplotlib notebook

xray_start = 71; xray_stop = 125;
log_sect_crop = log_sect_array[xray_start:xray_stop,:]
vminx, vmaxx = np.percentile(log_sect_array, (2.5, 99.8))
extent_xray = [q_sect[0], q_sect[-1], 0, (xray_stop-xray_start)/5]

plt.figure(figsize=(4,4))
plt.imshow(log_sect_crop,
            origin='lower', aspect='auto',
            vmin=vminx, vmax=vmaxx,
            interpolation='nearest',
            cmap='terrain',
            extent=extent_xray)

plt.xlabel(r'$q_{xy} \: (\AA^{-1})$')
plt.ylabel('Time (s)')
# Out:
# <img src="data:image/png;base64,..." width="384">
# Text(0,0.5,'Time (s)')

# %% [markdown]
# ### At what time does the blade pass? And when is the spectrum stable?

# %%
print('set xray_start to: {}'.format(14.2 / xray_dt))
print('set xray_stop to: {}'.format(25 / xray_dt))
# Out:
# set xray_start to: 70.99999999999999
# set xray_stop to: 125.0

# %% [markdown]
# ## Great, now let's work on the UV
#
# We're going to do an average filter on the straight channel to smooth it out.

# %%
straight0 = np.loadtxt(uv_straight[0], skiprows=17, comments='>')
waves = straight0[:,0]
straight_raw = np.array([np.transpose(np.loadtxt(tt,skiprows=17,comments='>')[:,1]) for tt in uv_straight])
straight_raw.shape
# Out:
# (1198, 2048)

# %%
smoothing = 7

straight_array = convolve2d(straight_raw,
                            np.ones((1,smoothing))/smoothing,
                            mode = 'same')

# %%
kicked_array = np.array([np.transpose(np.loadtxt(tt,skiprows=17,comments='>')[:,1]) for tt in uv_kicked])
kicked_array.shape
# Out:
# (1198, 2048)

# %% [markdown]
# ### Plot example spectra

# %%
w_start = 425; w_stop = 875
w_start_ind = np.where(waves>w_start)[0][0]
w_stop_ind = np.where(waves>w_stop)[0][0]
waves_crop = waves[w_start_ind:w_stop_ind]

# %matplotlib notebook
plt.figure(figsize=(4,3))
plt.plot(waves_crop,straight_array[-1,w_start_ind:w_stop_ind],
         waves_crop,kicked_array[-1,w_start_ind:w_stop_ind])
plt.xlabel('Wavelength (nm)')
plt.ylabel('Reflectance (%)')
# Out:
# <img src="data:image/png;base64,..." width="384">
# Text(0,0.5,'Reflectance (%)')

# %% [markdown]
# ## Find the spectrum where you'll start t=0

# %%
# %matplotlib notebook

spec_start = 0; spec_stop = straight_array.shape[0];
straight_crop = straight_array[spec_start:spec_stop,w_start_ind:w_stop_ind].clip(min=0.1,max=100)/100

vmins, vmaxs = np.percentile(straight_crop, (2.5, 99.8))
extent_wli = [waves[w_start_ind], waves[w_stop_ind], 0, (spec_stop-spec_start)/10]

plt.figure(figsize=(4,4))
plt.imshow(straight_crop,
                origin='lower', aspect='auto',
                vmin=vmins, vmax=vmaxs,
                interpolation='nearest',
                cmap='terrain',
                extent=extent_wli)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Time (s)')
plt.colorbar(fraction=0.047, pad=0.05).ax.tick_params(axis='y', direction='out')
# Out:
# <img src="data:image/png;base64,..." width="384">

# %% [markdown]
# ### At what time does the blade pass? Then calculate stop frame from xray stop frame

# %%
print('set uv_start to: {}'.format(13.7 / uv_dt))
print('set uv_stop to: {}'.format( (13.7 + (xray_stop-xray_start)*xray_dt) / uv_dt ))
# Out:
# set uv_start to: 136.99999999999997
# set uv_stop to: 245.0

# %% [markdown]
# ## Plot the straight and kicked spectra side-by-side

# %%
# %matplotlib notebook

spec_start = 137; spec_stop = 245;

straight_crop = straight_array[spec_start:spec_stop,w_start_ind:w_stop_ind].clip(min=0.1,max=100)/100
kicked_crop = kicked_array[spec_start+1:spec_stop+1,w_start_ind:w_stop_ind].clip(min=0.1,max=100)/100

vmins, vmaxs = np.percentile(straight_crop, (2.5, 99.8))
vmink, vmaxk = np.percentile(kicked_crop, (2.5, 99.8))
extent_wli = [waves[w_start_ind], waves[w_stop_ind], 0, (spec_stop-spec_start)/10]

f1 = plt.figure(figsize=(8,4))
ax11 = plt.subplot(121)
plt.imshow(straight_crop,
                origin='lower', aspect='auto',
                vmin=vmins, vmax=vmaxs,
                interpolation='nearest',
                cmap='terrain',
                extent=extent_wli)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Time (s)')

ax12 = plt.subplot(122, sharey=ax11)
plt.imshow(kicked_crop,
                origin='lower', aspect='auto',
                vmin=vmink, vmax=vmaxk,
                interpolation='nearest',
                cmap='terrain',
                extent=extent_wli)
plt.xlabel('Wavelength (nm)')
plt.colorbar(fraction=0.047, pad=0.05).ax.tick_params(axis='y', direction='out')

uu_file = os.path.join(os.path.split(figfolder)[0],'{}_uu.png'.format(run_name))
plt.savefig(uu_file, dpi=300, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="768">
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Calculate anisotropy and plot
#
# absorbance = -log(reflectance)
#
# anisotropy = (A_straight - A_kicked) / (A_straight + A_kicked)

# %%
aniso_mat = (-np.log(straight_crop)+np.log(kicked_crop))/(-np.log(straight_crop)-np.log(kicked_crop))

plt.figure(figsize=(5,4))
plt.imshow(aniso_mat,
                origin='lower', aspect='auto',
                vmin=-1, vmax=1,
                interpolation='nearest',
                cmap='PiYG',
                extent=extent_wli)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Time (s)')
plt.colorbar(fraction=0.04, pad=0.05).ax.tick_params(axis='y', direction='out')
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# ## Finally, plot xray and aniso side-by-side

# %%
f2 = plt.figure(figsize=(8,4))

ax21 = plt.subplot(121)
plt.imshow(log_sect_crop,
            origin='lower', aspect='auto',
            vmin=vminx, vmax=vmaxx,
            interpolation='nearest',
            cmap='terrain',
            extent=extent_xray)

plt.xlabel(r'$q_{xy} \: (\AA^{-1})$')
plt.ylabel('Time (s)')

ax22 = plt.subplot(122, sharey=ax21)
plt.imshow(aniso_mat,
            origin='lower', aspect='auto',
            vmin=-1, vmax=1,
            interpolation='nearest',
            cmap='PiYG',
            extent=extent_wli)

plt.xlabel('Wavelength (nm)')
plt.colorbar(fraction=0.05, pad=0.05).ax.tick_params(axis='y', direction='out')
xu_file = os.path.join(os.path.split(figfolder)[0],'{}_xu.png'.format(run_name))
plt.savefig(xu_file, dpi=300, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="768">
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Generate spectra images for the movie
#
# Previous cells must have been run for this to work.
#
# Also add a 2-second buffer before blade passage

# %%
# %matplotlib inline

xray_start_buf = int(xray_start - 2/xray_dt)

for ind,row in df.loc[df['movie_num']==main_movie].loc[df['shot_num'].between(xray_start_buf,xray_stop)].iterrows():

    data_file = row['fullpath']
    data_exp = row['exp_time']
    data = fabio.open(data_file).data
    data = np.flipud(data)
    
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = incident_angle, tilt_angle = tilt_angle,
                     detector=detector)

    imgt, qxy, qz = pg.transform_reciprocal(data, method='lut', correctSolidAngle=True, unit='A', dark=darkscale)
    corrimg = imgt-np.min(imgt)+1
    logimg = np.log(corrimg)
    
    figpath = os.path.join(figfolder, 'raw_waxs', row['filename'][:-9]+'{0:04d}.png'.format(row['shot_num']-xray_start_buf))
    print(figpath)
    
    clim = np.percentile(logimg, (2.5, 99.8))
    ppl.implot(logimg,qxy,qz,mode='rsma',cmap='terrain',clim=clim,xlim=(-0.2,2),ylim=(-0.05,2),show=False,filename=figpath)
    plt.close()
# Out:
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0000.png
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0001.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0002.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0003.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0004.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0005.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0006.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0007.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0008.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0009.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0010.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0011.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0012.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0013.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0014.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0015.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0016.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0017.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0018.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0019.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0020.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0021.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0022.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0023.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0024.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0025.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0026.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0027.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0028.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0029.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0030.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0031.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0032.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0033.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0034.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0035.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0036.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0037.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0038.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0039.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0040.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0041.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0042.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0043.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0044.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0045.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0046.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0047.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0048.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0049.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0050.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0051.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0052.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0053.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0054.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0055.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0056.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0057.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0058.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0059.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0060.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0061.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0062.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0063.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_0064.png

# %%
figwild = figpath[:-8]+"%04d.png"
movieout = os.path.join(figfolder, "waxs_movie.mp4")
print(figwild, '\n', movieout)
print('Paste this into cmd and run:')
# Run this to make the movie in command prompt
print("""F:\\GitHub\\ffmpeg\\bin\\ffmpeg.exe -framerate 5 -i "{}" -c:v libx264 -r 30 -pix_fmt yuv420p -vf scale=720:-2 -y "{}" """.format(figwild,movieout))
# Out:
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_%04d.png
#  F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\waxs_movie.mp4
# Paste this into cmd and run:
# F:\GitHub\ffmpeg\bin\ffmpeg.exe -framerate 5 -i "F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_waxs\n22tol20_hi_nogr_1_3_%04d.png" -c:v libx264 -r 30 -pix_fmt yuv420p -vf scale=720:-2 -y "F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\waxs_movie.mp4"

# %%
# %matplotlib inline

spec_start_buf = int(spec_start - 2/uv_dt)
straight_movie = straight_array[:,w_start_ind:w_stop_ind].clip(min=0.1,max=100)/100
kicked_movie = kicked_array[:,w_start_ind:w_stop_ind].clip(min=0.1,max=100)/100

for i in range(spec_start_buf, spec_stop):
    
    uvfigpath = os.path.join(figfolder, 'raw_uv', 'refl_{0:04d}.png'.format(i-spec_start_buf))
    print(uvfigpath)
    
    plt.figure(figsize=(4,4))
    
    plt.plot(waves_crop,straight_movie[i,:],
             waves_crop,kicked_movie[i+1,:])
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Reflectance')
    ax_temp = plt.gca()
    ax_temp.set_ylim([0,1])
    
    plt.savefig(uvfigpath, dpi=300, bbox_inches='tight')
    plt.close()
# Out:
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0000.png
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0001.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0002.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0003.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0004.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0005.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0006.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0007.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0008.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0009.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0010.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0011.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0012.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0013.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0014.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0015.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0016.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0017.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0018.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0019.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0020.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0021.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0022.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0023.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0024.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0025.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0026.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0027.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0028.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0029.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0030.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0031.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0032.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0033.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0034.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0035.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0036.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0037.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0038.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0039.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0040.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0041.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0042.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0043.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0044.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0045.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0046.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0047.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0048.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0049.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0050.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0051.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0052.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0053.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0054.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0055.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0056.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0057.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0058.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0059.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0060.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0061.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0062.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0063.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0064.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0065.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0066.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0067.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0068.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0069.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0070.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0071.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0072.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0073.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0074.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0075.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0076.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0077.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0078.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0079.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0080.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0081.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0082.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0083.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0084.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0085.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0086.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0087.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0088.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0089.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0090.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0091.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0092.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0093.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0094.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0095.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0096.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0097.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0098.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0099.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0100.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0101.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0102.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0103.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0104.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0105.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0106.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0107.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0108.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0109.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0110.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0111.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0112.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0113.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0114.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0115.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0116.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0117.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0118.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0119.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0120.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0121.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0122.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0123.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0124.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0125.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0126.png
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_0127.png

# %%
uvfigwild = uvfigpath[:-8]+"%04d.png"
uvmovieout = os.path.join(figfolder, "uv_movie.mp4")
print(uvfigwild, '\n', uvmovieout)
print('Paste this into cmd and run:')
# Run this to make the movie in command prompt
print("""F:\\GitHub\\ffmpeg\\bin\\ffmpeg.exe -framerate 10 -i "{}" -c:v libx264 -r 30 -pix_fmt yuv420p -vf scale=720:-2 -y "{}" """.format(uvfigwild,uvmovieout))
# Out:
# F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_%04d.png
#  F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\uv_movie.mp4
# Paste this into cmd and run:
# F:\GitHub\ffmpeg\bin\ffmpeg.exe -framerate 10 -i "F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\raw_uv\refl_%04d.png" -c:v libx264 -r 30 -pix_fmt yuv420p -vf scale=720:-2 -y "F:\N2200 Project\figures\chess_apr18\n22tol20_hi_nogr_1\uv_movie.mp4"

# %% [markdown]
# ### Run peak fits over sectors starting from 88 back to 5 deg.
# Initialize each fit from previous parameters

# %% [markdown]
# ### Perform composite peak fits

# %%
p100 = {'name': 'p100', 'set':1, 'cent': 2.3, 'min': 2.0, 'max': 3.0, 'sig': 0.1, 'amp': 1000, 'lb': 1.5, 'ub': 3.8}

p001 = {'name': 'p001', 'set':2, 'cent': 4.5, 'min': 4.0, 'max': 4.7, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}
p200 = {'name': 'p200', 'set':2, 'cent': 4.9, 'min': 4.7, 'max': 5.5, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}

p300 = {'name': 'p300', 'set':4, 'cent': 7.4, 'min': 7.0, 'max': 8.0, 'sig': 0.1, 'amp': 10, 'lb': 6.4, 'ub': 19.5}

p001a ={'name': 'p001a','set':4, 'cent': 8.8, 'min': 8.6, 'max': 9.0, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 19.5}
p002 = {'name': 'p002', 'set':4, 'cent': 9.5, 'min': 9.3, 'max': 9.8, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}
p400 = {'name': 'p400', 'set':4, 'cent': 9.9, 'min': 9.7, 'max': 10.3, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}

phalo ={'name': 'phalo', 'set':4, 'cent': 14, 'min': 12, 'max': 15, 'sig': 0.2, 'amp': 10, 'lb': 14, 'ub': 19.5}
p010 = {'name': 'p010', 'set':4, 'cent': 16.0, 'min': 15.2, 'max': 16.5, 'sig': 0.1, 'amp': 10, 'lb': 14, 'ub': 19.5}
p002a ={'name': 'p002a','set':4, 'cent': 17.7, 'min': 17.2, 'max': 18, 'sig': 0.1, 'amp': 10, 'lb': 14, 'ub': 19.5}

df = pd.DataFrame.from_dict([p100,p001,p200,p300,p001a,p400,phalo,p010,p002a]) #p002
df

# %%
x = q_sect
y = int_sect
color_list = ['#3cb44b','#0082c8','#f58231','#911eb4','#800000','#000080','#808000']
f1 = plt.figure()
plt.semilogy(x, y, 'r-')

for i in df['set'].unique():
    
    df_peaks = df.loc[df.set==i]
    
    # Build bounded x and y vectors
    lb = df_peaks.iloc[0].lb
    ub = df_peaks.iloc[0].ub
    lb_ind = int(np.where(x>=lb)[0][0])
    ub_ind = int(np.where(x>=ub)[0][0])
    xb = x[lb_ind:ub_ind]
    yb = y[lb_ind:ub_ind]
    
    # Initialize Baseline model
    comp_mod = []
    
    if i not in [1,2]:
        lin_mod = ConstantModel(prefix='lin_')
        pars = lin_mod.make_params(c=yb.min())
        comp_mod.append(lin_mod)
    else:
        lin_mod = ExponentialModel(prefix='lin_')
        pars = lin_mod.guess(y,x=x)
        comp_mod.append(lin_mod)

    # Add peaks
    for index, peak in df_peaks.iterrows():
        prefix = peak['name']+'_'
        peak_temp  = VoigtModel(prefix=prefix)
        
        pars.update( peak_temp.make_params())
        pars[prefix+'center'].set(peak['cent'], min=peak['min'], max=peak['max'])
        pars[prefix+'sigma'].set(peak['sig'])
        pars[prefix+'amplitude'].set(peak['amp'], min=0)
        
        comp_mod.append(peak_temp)
    
    # Build composite model
    comp_mod = np.sum(comp_mod)
    out = comp_mod.fit(yb, pars, x=xb)
    params_dict=out.params.valuesdict()
    
    # Store peak features in original dataframe
    for peak, prop in [s.split('_') for s in list(params_dict.keys())]:
        df.loc[df.name==peak,prop] = params_dict[peak+'_'+prop]
    
    # Add peaks to plot
    comps = out.eval_components(x=xb)
    plt.semilogy(xb, out.eval(x=xb), '-', color = color_list[i])
    for c in comps:
        try:
            plt.semilogy(xb, comps[c], '--', color = color_list[i])
        except:
            const_eval = np.ones(xb.shape)*comps[c]
            plt.semilogy(xb, const_eval, '--', color = color_list[i])

# Show the plot
f1.axes[0].set_ylim( bottom=np.min(y)/10, top=np.max(y)*1.3 )
plt.show()

# %%
df_pole = pd.DataFrame()

for d in range(88,6,-2):
    
    print(d)
    
    # Get I vs Q for angle d
    int_sect, q_sect = pg.profile_sector(data, npt=1000, chi_pos=d,
                                     chi_width=4, radial_range=(1.35, 20),
                                     correctSolidAngle=True,
                                     method='lut', dark=dark)
    
    # Run peak fits, initialized from previous fit's parameters
    x = q_sect
    y = int_sect
    
    df_prev = df
    
    for i in df['set'].unique():
        
        df_peaks = df_prev.loc[df.set==i]

        # Build bounded x and y vectors
        lb = df_peaks.iloc[0].lb
        ub = df_peaks.iloc[0].ub
        lb_ind = int(np.where(x>=lb)[0][0])
        ub_ind = int(np.where(x>=ub)[0][0])
        xb = x[lb_ind:ub_ind]
        yb = y[lb_ind:ub_ind]

        # Initialize Baseline model
        comp_mod = []

        if i not in [1,2]:
            lin_mod = ConstantModel(prefix='lin_')
            pars = lin_mod.make_params(c=yb.min())
            comp_mod.append(lin_mod)
        else:
            lin_mod = ExponentialModel(prefix='lin_')
            pars = lin_mod.guess(y,x=x)
            comp_mod.append(lin_mod)

        # Add peaks
        for index, peak in df_peaks.iterrows():
            prefix = peak['name']+'_'
            peak_temp  = VoigtModel(prefix=prefix)

            pars.update( peak_temp.make_params())
            pars[prefix+'center'].set(peak['center'], min=peak['min'], max=peak['max'])
            pars[prefix+'sigma'].set(peak['sigma'])
            pars[prefix+'amplitude'].set(peak['amplitude'], min=0)

            comp_mod.append(peak_temp)

        # Build composite model
        comp_mod = np.sum(comp_mod)
        out = comp_mod.fit(yb, pars, x=xb)
        params_dict=out.params.valuesdict()

        # Store peak features in original dataframe
        for peak, prop in [s.split('_') for s in list(params_dict.keys())]:
            df.loc[df.name==peak,prop] = params_dict[peak+'_'+prop]
        df['chi']=d

    # Store results in pole figure dataframe
    df_pole = df_pole.append(df)

# %%
df_pole[df_pole.name=='p200']

# %%
pole_list

# %%
h200 = [dfp['height'].loc[2] for dfp in df_pole['peaks'].tolist()]
plt.figure()
plt.plot(df_pole['chi'].tolist(),h200)

# %% [markdown]
# ### Compute d-spacing, Herman's Orientation

# %%
df['d-space']=2*np.pi / df['center'] * 10
df

# %%
def Hermans(ii, chi):
    sin_chi = np.sin(np.deg2rad(chi))
    cos2chi = np.cos(np.deg2rad(chi)) ** 2
    return np.sum(ii * cos2chi * sin_chi) / np.sum(ii * sin_chi)

def interp_nans(data):
    mask = np.isnan(data)
    data[mask] = np.interp(np.flatnonzero(mask), np.flatnonzero(~mask), data[~mask])
    return data

# %% [markdown]
# ### Chi-profile, radially integrated, for Herman's calculation

# %%
p200_q = float(df['center'][df['name']=='p200'])

cake, chi = pg.profile_chi(data, npt=200,
                           radial_pos=p200_q, radial_width=.3,
                           chi_range=(-88,88),
                           correctSolidAngle=True,
                           method='lut', dark=dark)

ppl.plot(chi,np.abs(interp_nans(cake) * np.sin(np.deg2rad(chi))),mode='chi')
print('Hermans Orientation Factor: ', Hermans(interp_nans(cake),chi))

# %% [markdown]
# ### q-chi map, just because it's possible

# %%
intensity, q_abs, chi = pg.transform_polar(data,
                                           npt=(2000, 400), q_range=(0,20),
                                           correctSolidAngle=True,
                                           method='splitpix', dark=dark)

ppl.implot(intensity, q_abs, chi, mode='polar', cmap='terrain', clim=np.percentile(intensity,(0.1,99.5)))

# %% [markdown]
# ### Generate cropped, processed spectrum for all files
#
# Previous cells must have been run for this to work.

# %%
for ind,row in df.iterrows():
    
    data = fabio.open(row['fullpath']).data
    data = np.flipud(data)
    
    if row['exp_time'] == 30:
        dark = np.flipud(fabio.open(dark30file).data)
    else: 
        dark = np.flipud(fabio.open(dark90file).data)
    
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                         rot1 = rot1, rot2 = rot2, rot3 = rot3,
                         wavelength = wl, sample_orientation = sample_orientation,
                         incident_angle = incident_angle, tilt_angle = tilt_angle,
                         detector=detector)

    imgt, qxy, qz = pg.transform_reciprocal(data, method='lut', correctSolidAngle=True, unit='A', dark=dark)
    logimg = np.log(imgt+1)
    
    figfile = (row['fullpath'].split('.')[:-1][0]+'.png').replace('data','figures')
    print(figfile)
    clim = np.percentile(logimg[logimg>0], (3, 99.99))
    ppl.implot(logimg,qxy,qz,mode='rsma',cmap='terrain',clim=clim,xlim=(-.6,2),ylim=(-.05,2),show=False,filename=figfile)
    plt.close()

# %% [markdown]
# ### Write a master function to automate analysis

# %%
def analyze_n22(dfrow):
    
    # Open file, get data and dark spectra
    data_file = dfrow['fullpath']
    print(dfrow['filename'])
    data = fabio.open(data_file).data
    data = np.flipud(data)

    if dfrow['exp_time'] == 30:
        dark = np.flipud(fabio.open(dark30file).data)
    else: 
        dark = np.flipud(fabio.open(dark90file).data)
        
        
    # Setup detector and transform
    ### Detector pixel size
    det_pix = [73.242e-6, 73.242e-6]
    detector = pyFAI.detectors.Detector(det_pix[0], det_pix[1])

    ### Wavelength
    wl = 0.976254e-10

    ### Center-pixel and sample-to-detector distance
    centerx =  1532.42
    centery = data.shape[0]-3034.23   # This is because I had to flip it upside-down
    sdd = 0.339316

    ### Beamcenter from sample view in meters from lower left of detector
    poni1 = centery * det_pix[1]; poni2 = centerx * det_pix[0]

    ### detector rotations from sample view
    rot1 = deldel /180 * np.pi # move detector to right, in-plane angle# in radians
    rot2 = 0.0    /180 * np.pi # move detector down, out-of-plane angle
    rot3 = 0.0    /180 * np.pi # clockwise rotation

    ### Orientations and Angles
    sample_orientation = 1    # 1 is horizontal, 2 is vertical
    incident_angle = dfrow['theta']     # indicent angle in deg
    tilt_angle = 0            # tilt angle of sample in deg (misalignment in "chi")
    
    ### Initialize the transform
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = incident_angle, tilt_angle = tilt_angle,
                     detector=detector)
    
    # in-plane profile for analysis
    int_in, q_in = pg.profile_ip_box(data, npt=1000, op_pos=0,
                                 op_width=1, ip_range=(1.35, 20),
                                 correctSolidAngle=True,
                                 method='lut', dark=dark)
    
    # Fitting parameters
    p100 = {'name': 'p100', 'set':1, 'cent': 2.3, 'min': 2.2, 'max': 2.6, 'sig': 0.1, 'amp': 1000, 'lb': 1.5, 'ub': 3.8}

    p001 = {'name': 'p001', 'set':2, 'cent': 4.5, 'min': 4.3, 'max': 4.7, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}
    p200 = {'name': 'p200', 'set':2, 'cent': 4.9, 'min': 4.7, 'max': 5.0, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}

    p300 = {'name': 'p300', 'set':3, 'cent': 7.4, 'min': 7.0, 'max': 8.0, 'sig': 0.1, 'amp': 10, 'lb': 6.4, 'ub': 8.3}

    p001a ={'name': 'p001a','set':4, 'cent': 8.8, 'min': 8.6, 'max': 9.0, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}
    p002 = {'name': 'p002', 'set':4, 'cent': 9.5, 'min': 9.3, 'max': 9.8, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}
    p400 = {'name': 'p400', 'set':4, 'cent': 9.9, 'min': 9.7, 'max': 10.3, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}

    p002a ={'name': 'p002a','set':5, 'cent': 17.7, 'min': 17.2, 'max': 18, 'sig': 0.1, 'amp': 10, 'lb': 16.7, 'ub': 18.7}

    df = pd.DataFrame.from_dict([p100,p001,p200,p300,p001a,p002,p400,p002a])
    
    # Perform Peak Fits
    x = q_in
    y = int_in

    for i in df['set'].unique():

        df_peaks = df.loc[df.set==i]

        # Build bounded x and y vectors
        lb = df_peaks.iloc[0].lb
        ub = df_peaks.iloc[0].ub
        lb_ind = int(np.where(x>=lb)[0][0])
        ub_ind = int(np.where(x>=ub)[0][0])
        xb = x[lb_ind:ub_ind]
        yb = y[lb_ind:ub_ind]

        # Initialize Baseline model
        comp_mod = []
        lin_mod = LinearModel(prefix='lin_')
        pars = lin_mod.make_params(intercept=yb.min(), slope=0)
        comp_mod.append(lin_mod)

        # Add peaks
        for index, peak in df_peaks.iterrows():
            prefix = peak['name']+'_'
            peak_temp  = VoigtModel(prefix=prefix)

            pars.update( peak_temp.make_params())
            pars[prefix+'center'].set(peak['cent'], min=peak['min'], max=peak['max'])
            pars[prefix+'sigma'].set(peak['sig'])
            pars[prefix+'amplitude'].set(peak['amp'], min=0)

            comp_mod.append(peak_temp)

        # Build composite model
        comp_mod = np.sum(comp_mod)
        out = comp_mod.fit(yb, pars, x=xb)
        params_dict=out.params.valuesdict()

        # Store peak features in original dataframe
        for peak, prop in [s.split('_') for s in list(params_dict.keys())]:
            df.loc[df.name==peak,prop] = params_dict[peak+'_'+prop]
            
    # Store results of peak fits in dfrow
    dfrow['peak_fits'] = df
    
    
    # Get Herman's Orientation and store
    p200_q = float(df['center'][df['name']=='p200'])
    
    cake, chi = pg.profile_chi(data, npt=200,
                               radial_pos=p200_q, radial_width=.3,
                               chi_range=(3,88),
                               correctSolidAngle=True,
                               method='lut', dark=dark)
    
    dfrow['Hermans'] = Hermans(interp_nans(cake),chi)
    
    return dfrow

# %%
df_test = df.iloc[0]
df_test

# %%
res = analyze_n22(df_test)

# %%
df_res = pd.DataFrame()
for i,row in df.iterrows():
    try:
        df_res = df_res.append(analyze_n22(row))
    except:
        pass
    
df_res

# %%
df_res[['filename','solvent','speed','grooves','sample_phi','theta','Hermans']]

# %%
df_res =

# %%
df_res.to_csv(path_or_buf='n22_waxs_results.csv')

# %%
df_res.to_pickle('n22_waxs_pickle')

# %%
df_new = pd.read_pickle('n22_waxs_pickle')
df_new

# %%
df_new
